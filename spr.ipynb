# %%
import pandas as pd
import os
import glob
from gtts import gTTS
import gradio as gr
from fuzzywuzzy import fuzz
from bing_image_downloader import downloader
import zipfile

# %%
## Подготовка данных
# Загружаем датасет с растениями парка Зарядье
df_plants = pd.read_csv("C:\Data_sets\data-60861-2024-08-06.csv", delimiter=';')
# Удаляем строки, где ID равен 'Код', и сбрасываем индексы
df_plants = df_plants[df_plants['ID'] != 'Код'].reset_index(drop=True)

# %%
# Формируем список латинских наименований растений
latin_names = df_plants['LatinName'].tolist()

print(latin_names)
# Out:
# ['Picea abies', 'Pinus sylvestris', 'Querqus robur', 'Tilia cordata', 'Acer platanoides', 'Malus baccata', 'Acer saccharinum', 'Sorbus aucuparia', 'Padus avium', 'Betula pendula', 'Betula pubescens', 'Salix alba', 'Salix alba x blanda', 'Salix babylonica «Sverdlovskaja izvilistaja 2»', 'Juniperus communis Hornibrooki', 'Juniperus sabina Mas', 'Pinus pumila', 'Betula nana', 'Salix lanata', 'Salix glauca callicarpaea', 'Coryllus avellana', 'Euonimus verrucosus', 'Sambucus racemosa', 'Rosa canina', 'Spiraea chamaedryfolia', 'Salix ledebouriana x S. purpurea hybrida Sukaszewii', 'Salix purpurea', 'Viburnum opulus', 'Berberis vulgaris', 'Amygdalis nana', 'Cerassus fruticjsa', 'Lonicera tatarica', 'Acer tataricum', 'Syringa vulgaris', 'Rosa rugosa', 'Spiraea bumalda', 'Spiraea vanhouttei', 'Potentilla fruticosa', 'Caltha palustris', 'Carex capillaris', 'Carex capitata', 'Carex caespitosa', 'Cerastium alpinum', 'Dryas octopetala', 'Rubus arcticus', 'Polygonum viviparum', 'Saxifraga caespitosa', 'Sedum acre', 'Sedum spurium', 'Ajuga reptans', 'Asarum europeum', 'Sedum hybridum', 'Lusula pilosa', 'Majanthemum bifolium', 'Gymnocarpium dryopteris', 'Dryopteris dilatana', 'Antennaria dioica', 'Campanula persicifolia', 'Convallaria majalis', 'Dianthus deltoides', 'Melica nutans', 'Verinica incana', 'Pulsatilla patens', 'Aruncus vulgaris', 'Lisimachia nummularia', 'Millium effusum', 'Polygonatum multiflorum', 'Geranium sylvaticum', 'Geranium sanguineum', 'Primula elatior', 'Carex pillosa', 'Galeobdolon luteum', 'Asperula odorata', 'Brachypodium sylvaticum', 'Veronica chamaedrys', 'Myosotis sylvestris', 'Anemone nemorosa', 'Anemone ranunculoides', 'Corydalis cava', 'Corydalis solida', 'Thymus serpyllum', 'Hieracium umbellatum', 'Alopecurus pratensis', 'Dactylis glomerata', 'Festuca pratensis', 'Achillea millefolium', 'Alchemilla vulgaris', 'Campanula glomerata', 'Campanula patula', 'Centaurea jacea', 'Centaurea phrygia', 'Centaurea scabiosa', 'Cichorium intybus', 'Veronica longifolia', 'Geranium pratense', 'Glechoma hederacea', 'Hypericum maculatum', 'Leucanthemum vulgare', 'Molinia cearulea', 'Melilotus albus', 'Melilotus officinalis', 'Potentilla argentea', 'Prunella vulgaris.', 'Saponaria officinalis', 'Senecio jacobaea', 'Tanacetum vulgare', 'Calamagrostis x acutiflora', 'Trifolium repens', 'Trifolium pratense', 'Gagea lutea', 'Elymus giganteum', 'Anemone sylvestris', 'Arthemisia pontica', 'Centaurea ruthenica', 'Echinops ritro', 'Euphorbia cyparissias', 'Iris aphylla', 'Koeleria cristata', 'Linum perenne', 'Salvia nemorosa', 'Stipa capillata', 'Verbascum phoenicum', 'Veronica spicata', 'Crambe cordifolia', 'Crambe tatarica', 'Eryngium planum', 'Gypsophyla paniculata', 'Paeonia tenuifolia', 'Clematis integrifolia', 'Tulipa biebersteiniana', 'Iris pseudacorus', 'Iris sibirica', 'Eupatorium purpureum', 'Lithrum salicaria', 'Myosotis sylvestris.', 'Pelasites ampulus', 'Trollius europaeus', 'Polygonum bistorta', 'Lichnis flos-cuculi', 'Phalaris arundinaceae', 'Astilbe hybrida', 'Hemerocalis hybrida', 'Deschampsia caespitosa', 'Thelypteris palustris', 'Ranunculus repens pleniflorus', 'Filipendula ulmaria', 'Sagittaria latifolia', 'Acorus calamus', 'Typha laxmannii', 'Carex paniculata', 'Bolboschoenus maritimus', 'Butomus umbellatus', 'Menyanthes trifoliata', 'Nyphar lutea ssp.lutea', 'Nymphaea candida']

# %%
## Формируем архив с картинками растений
# Скачиваем картинки для каждого латинского наименования растения
for latin_name in latin_names:
    downloader.download(
        latin_name,
        limit=3,  # количество картинок для каждого растения
        output_dir='plant_images',
        adult_filter_off=True,
        force_replace=False,
        timeout=60
    )

# Формируем zip архив
with zipfile.ZipFile('plant_images.zip', 'w') as zipf:
    for latin_name in latin_names:
        image_dir = f'plant_images/{latin_name}'
        if os.path.exists(image_dir):
            for image in os.listdir(image_dir):
                image_path = os.path.join(image_dir, image)
                zipf.write(image_path, f'{latin_name}/{image}')
# Out:
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Picea abies
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.conifers.org/pi/pi/a/abies02.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.vdberk.fr/media/410420/picea_abies.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://phytoimages.siu.edu/users/paraman1/8_17_06_12/234567/PiceaAbies2.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Pinus sylvestris
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.vdberk.com/media/414230/pinus-sylvestris.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.treesandshrubsonline.org/site/assets/files/6733/pinus-sylvestris.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.bighearttreecare.co.uk/wp-content/uploads/2019/12/Pinus-sylvestris-Scots-pine-1-scaled.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Querqus robur
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 2 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://boletosdeorum.pt/wp-content/uploads/2019/12/Quercus-robur_site-1024x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://bugwoodcloud.org/images/1536x1024/1379021.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 94 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from http://blogs.ubc.ca/landscapeplants2/files/2015/11/15-12.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Tilia cordata
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.vdberk.com/media/87990/tilia_cordata_1-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.treesandshrubsonline.org/site/assets/files/8090/tilia-cordata-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://plantsam.com/wp-content/uploads/2016/06/Tilia-cordata-480-1600x1067.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Acer platanoides
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Sapindaceae/acer-platanoides-le-ahaines.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://pflanzenbestimmung.info/wp-content/uploads/2021/03/Acer-platanoides-12.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://pepinierelocas.com/wp-content/uploads/2019/03/acer-platanoides-drummondii-1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Malus baccata
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Rosaceae/malus-baccata-fl-azinovjev.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.treesandshrubsonline.org/site/assets/files/6279/malus-baccata-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Rosaceae/malus-baccata-fr-azinovjev.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Acer saccharinum
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://i.pinimg.com/originals/9b/d2/29/9bd22970e19a8893adfc6f2afb8b88a1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.vdberk.com/media/6110/acer-saccharinum.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.vdberk.com/media/6110/acer_saccharinum_5.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Sorbus aucuparia
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.vdberk.co.uk/media/83330/sorbus_aucuparia_1-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://beechmount.ie/wp-content/uploads/2019/03/sorbus-aucuparia4.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Rosaceae/sorbus-aucuparia-le-dkausen-c.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Padus avium
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://agroatlas.ru/content/related/Padus_avium/Padus_avium.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.plantarium.ru/dat/plants/2/233/239233_abde29b2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.plantarium.ru/dat/plants/3/348/95348_a3485703.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Betula pendula
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Betulaceae/betula-pendula-fr-rvid-b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://upload.wikimedia.org/wikipedia/commons/c/c4/Betula_pendula_tree_Bulgaria.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://upload.wikimedia.org/wikipedia/commons/4/46/Betula_pendula_001.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Betula pubescens
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.mountroyalseeds.com/wp-content/uploads/2016/10/betula-pubescens_2-640x427.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.vdberk.co.uk/media/12590/betula-pubescens.jpg
# [Error]Invalid image, not saving https://www.vdberk.co.uk/media/12590/betula-pubescens.jpg
#
# [!] Issue getting: https://www.vdberk.co.uk/media/12590/betula-pubescens.jpg
# [!] Error:: Invalid image, not saving https://www.vdberk.co.uk/media/12590/betula-pubescens.jpg
#
# [%] Downloading Image #2 from https://www.mountroyalseeds.com/wp-content/uploads/2016/10/Betula-pubescens-subsp.-carpatica_1-480x640.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 95 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from http://www.plantsystematics.org/users/dws/11_10_05/Betula/Betula_pubescens5.JPG
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Salix alba
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/b/b9/Salix_alba_'Tristis'_02_by_Line1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Salicaceae/salix-alba-ha-azinovjev.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://hagetisse.com/wp-content/uploads/2020/06/schietwilg-salix-alba-bloeivorm.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Salix alba x blanda
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://hagetisse.com/wp-content/uploads/2020/06/schietwilg-salix-alba-bloeivorm.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Salicaceae/salix-alba-fr-rvid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Salicaceae/salix-alba-ha-azinovjev.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Salix babylonica «Sverdlovskaja izvilistaja 2»
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.coldstreamfarm.net/wp-content/uploads/2018/06/willow_weeping_istock_80298053_xlarge.jpg
# [!] Issue getting: https://www.coldstreamfarm.net/wp-content/uploads/2018/06/willow_weeping_istock_80298053_xlarge.jpg
# [!] Error:: <urlopen error [Errno 11001] getaddrinfo failed>
# [%] Downloading Image #1 from http://2.bp.blogspot.com/-RbvIhs6B94Q/VRA9buLe6vI/AAAAAAAADAQ/FNK33sTe2c0/s1600/Salix%2Bbabylonica%2B-%2BBabylon%2BWillow%2B-%2BWeeping%2BWillow%2B12.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/53/22/2c/53222c4cae543b56b1645c5ce2dc5e5b.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 34 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://s3.amazonaws.com/eit-planttoolbox-prod/media/images/salix_babylonica_Kent_McFarland_ccbync20.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Juniperus communis Hornibrooki
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.evansnursery.net/Plant-Name/_ccLib/image/plantstock/WEB/WEB-001514.jpg
# [!] Issue getting: https://www.evansnursery.net/Plant-Name/_ccLib/image/plantstock/WEB/WEB-001514.jpg
# [!] Error:: <urlopen error [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера>
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/3/34/Juniperus_communis_Haweswater.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.treesandshrubsonline.org/site/assets/files/5910/juniperus-communis.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://d147a5vd7kzml6.cloudfront.net/img/appeltern_nl/150573/388x517/resize:fixed/juniperus_communis_hornibrookii.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Juniperus sabina Mas
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://vserost.com/d/8389d6a3bd664adacfe91f1b25e3e0a5.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/66/67/b4/6667b4c9653634d7dfc559a01cfbbfdb.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://kedrpitomnik.ru/wp-content/uploads/2021/03/казацкий-мас.jpg
# [!] Issue getting: https://kedrpitomnik.ru/wp-content/uploads/2021/03/казацкий-мас.jpg
# [!] Error:: 'ascii' codec can't encode characters in position 32-39: ordinal not in range(128)
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 33 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://kurowski.pl/images/katalog/1100_900/juniperus-sabina-mas_big.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Pinus pumila
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.coniferkingdom.com/wp-content/uploads/2020/12/Pinus-pumila-Glauca.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn2.bigcommerce.com/server5800/90ad9/images/stencil/1280x1280/products/1566/2068/PinuspumilaBlueDwarf_0261__17589.1481761744.jpg?c=2
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.coniferkingdom.com/wp-content/uploads/2020/12/Pinus-pumila-Dwarf-Blue-3-gal.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Betula nana
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.cramer.ca/wp-content/uploads/2014/04/Betula-Nana-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://alchetron.com/cdn/betula-nana-b59bd991-3c52-495c-9f86-6123df76ea3-resize-750.jpeg
# [!] Issue getting: https://alchetron.com/cdn/betula-nana-b59bd991-3c52-495c-9f86-6123df76ea3-resize-750.jpeg
# [!] Error:: <urlopen error [WinError 10054] Удаленный хост принудительно разорвал существующее подключение>
# [%] Downloading Image #2 from https://www.leendersplants.nl/public/data/image/article/1591/1972/large/betula-nana-golden-treasure-eu2014-0652.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 32 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from http://www.freenatureimages.eu/plants/Flora%20A-B/Betula%20nana%2C%20Dwarf%20Birch/Betula%20nana%2014%2C%20Saxifraga-Hans%20Dekker.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Salix lanata
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.treesandshrubsonline.org/site/assets/files/7715/salix-lanata-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://d2seqvvyy3b8p2.cloudfront.net/034137c377c7ee47497e2a961648d950.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://cdn.shopify.com/s/files/1/1069/2032/products/Salix_lanata_1_nbrcg_wi_1024x1024.JPG?v=1456421401
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Salix glauca callicarpaea
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://phytoimages.siu.edu/users/paraman1/10_18_16_1/Upload18Oct16a/266SalixGlauca.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://alchetron.com/cdn/salix-glauca-ac92b01a-d6ab-4580-9fa9-88da9c46949-resize-750.jpeg
# [!] Issue getting: https://alchetron.com/cdn/salix-glauca-ac92b01a-d6ab-4580-9fa9-88da9c46949-resize-750.jpeg
# [!] Error:: <urlopen error [WinError 10054] Удаленный хост принудительно разорвал существующее подключение>
# [%] Downloading Image #2 from https://www.honey-plants.com/img/picforcontent/salix-glauca_852_large.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://alchetron.com/cdn/salix-glauca-6bcc5f5c-c90c-4939-a434-dbf747b2308-resize-750.jpeg
# [!] Issue getting: https://alchetron.com/cdn/salix-glauca-6bcc5f5c-c90c-4939-a434-dbf747b2308-resize-750.jpeg
# [!] Error:: <urlopen error [WinError 10054] Удаленный хост принудительно разорвал существующее подключение>
# [%] Downloading Image #3 from https://c1.staticflickr.com/7/6077/6081105011_ea5ee255ae_b.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Coryllus avellana
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.nature-and-garden.com/wp-content/uploads/sites/4/2018/09/corylus-avellana-harvest.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/40/09/ee/4009eec3ec3713661ed26809663b0dde.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://de.academic.ru/pictures/dewiki/67/Corylus_avellana_001.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Euonimus verrucosus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.plantarium.ru/dat/plants/1/129/677129_014f4f78.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.plantarium.ru/dat/plants/7/793/563793_fca39504.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.plantarium.ru/dat/plants/6/611/586611_d41c9a69.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Sambucus racemosa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Adoxaceae/sambucus-racemosa-fl-ahaines-b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://galasearch.de/system/images/24330/original/Sambucus_racemosa_Roter_Holunder_11.jpg?1510779591
# [!] Issue getting: https://galasearch.de/system/images/24330/original/Sambucus_racemosa_Roter_Holunder_11.jpg?1510779591
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>
# [%] Downloading Image #2 from https://mareklandscaping.com/wp-content/uploads/2019/02/Sambucus-pubens-Fruit1.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 94 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://media.ooreka.fr/public/image/sambucus-racemosa-full-13609365.jpg
# [!] Issue getting: https://media.ooreka.fr/public/image/sambucus-racemosa-full-13609365.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #3 from https://nativeplantspnw.com/wp-content/uploads/2017/03/Sambucus-racemosa-624x469.png
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Rosa canina
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/1/10/Rosa_canina_flower_Luc_Viatour.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/e/e3/Rosa_canina_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://botanyphoto.botanicalgarden.ubc.ca/wp-content/uploads/2017/11/rosa-canina.jpg
# [!] Issue getting: http://botanyphoto.botanicalgarden.ubc.ca/wp-content/uploads/2017/11/rosa-canina.jpg
# [!] Error:: HTTP Error 404: Not Found
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 94 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from http://d2seqvvyy3b8p2.cloudfront.net/dace44ccf7e3ab4a777fa34536e280a9.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Spiraea chamaedryfolia
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://tahvoset.fi/wp-content/uploads/2012/04/Spiraea-chamaedryfolia.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Rosaceae/spiraea-chamaedryfolia-le-amoro2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/a7/2b/02/a72b02a38f475dae0fda828214ef4cf6.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Salix ledebouriana x S. purpurea hybrida Sukaszewii
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://khartasia-crcc.mnhn.fr/sites/default/files/images/salix-purpurea-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://dumonthorticulture.fr/wp-content/uploads/2020/04/Salix-purpurea-nana-768x768.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://m.media-amazon.com/images/I/915AsXk8PdL._AC_SL1500_.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Salix purpurea
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://khartasia-crcc.mnhn.fr/sites/default/files/images/salix-purpurea6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://khartasia-crcc.mnhn.fr/sites/default/files/images/salix-purpurea-7.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://dumonthorticulture.fr/wp-content/uploads/2020/04/Salix-purpurea-nana-768x768.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Viburnum opulus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://img.crocdn.co.uk/images/products2/pl/00/00/00/44/pl0000004473.jpg?width=940&amp;height=940
# [!] Issue getting: https://img.crocdn.co.uk/images/products2/pl/00/00/00/44/pl0000004473.jpg?width=940&amp;height=940
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from http://img.crocdn.co.uk/images/products2/pl/00/00/00/44/pl0000004473_card2_lg.jpg
# [!] Issue getting: http://img.crocdn.co.uk/images/products2/pl/00/00/00/44/pl0000004473_card2_lg.jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from http://gammonlandscapenursery.com/wp-content/uploads/2014/02/Viburnum-opulus-roseum.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 95 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #2 from https://galasearch.de/system/images/24160/original/Viburnum_opulus_var._americanum_Gemeiner_Schneeball_13.jpg?1509311847
# [!] Issue getting: https://galasearch.de/system/images/24160/original/Viburnum_opulus_var._americanum_Gemeiner_Schneeball_13.jpg?1509311847
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>
# [%] Downloading Image #2 from https://horticulture.co.uk/wp-content/uploads/2023/02/viburnumopulusroseum-header-2-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://maryflower.co.nz/wp-content/uploads/2018/10/20181025_133748.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Berberis vulgaris
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://nutrawiki.org/wp-content/uploads/2015/08/Berberis_vulgaris.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://theoriginalgarden.com/Argazkiak/Fotos/BERBERISVULGARISsubsp.AUSTRALIS(B.hispanica)Agracejoandaluz_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://upload.wikimedia.org/wikipedia/commons/7/7b/Berberis_vulgaris_.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Amygdalis nana
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.plantarium.ru/dat/plants/6/637/568637_c268d0e2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.plantarium.ru/dat/plants/1/113/446113_8bfaf13c.jpg
# [Error]Invalid image, not saving https://www.plantarium.ru/dat/plants/1/113/446113_8bfaf13c.jpg
#
# [!] Issue getting: https://www.plantarium.ru/dat/plants/1/113/446113_8bfaf13c.jpg
# [!] Error:: Invalid image, not saving https://www.plantarium.ru/dat/plants/1/113/446113_8bfaf13c.jpg
#
# [%] Downloading Image #2 from https://www.plantarium.ru/dat/plants/3/360/569360_44d8aa83.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://live.staticflickr.com/2081/5714961515_88b4e0e5e7_b.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Cerassus fruticjsa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://media.sciencephoto.com/image/c0131720/800wm/C0131720-Sour_Cherry_Prunus_cerasus_Achat_.jpg
# [!] Issue getting: https://media.sciencephoto.com/image/c0131720/800wm/C0131720-Sour_Cherry_Prunus_cerasus_Achat_.jpg
# [!] Error:: <urlopen error [WinError 10054] Удаленный хост принудительно разорвал существующее подключение>
# [%] Downloading Image #1 from https://www.plantarium.ru/dat/plants/3/319/197319_dec54724.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://d2seqvvyy3b8p2.cloudfront.net/5b3e8344c5a784e1fa12512d4abcff0c.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from http://upload.wikimedia.org/wikipedia/commons/1/1d/Sauerkirschenfrucht_Prunus_cerasus_1.JPG
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Lonicera tatarica
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://plantsam.com/wp-content/uploads/2021/05/Lonicera-tatarica.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Caprifoliaceae/lonicera-tatarica-fr-ahaines-c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://plantsam.com/wp-content/uploads/2021/05/Lonicera-tatarica-1-1536x1536.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Acer tataricum
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.vdberk.co.uk/media/6600/acer-tataricum-subsp-ginnala.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Sapindaceae/acer-tataricum-fr-pnw.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Sapindaceae/acer-tataricum-ha-pnw.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Syringa vulgaris
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/3/35/Lilac_Flower%26Leaves%2C_SC%2C_Vic%2C_13.10.2007.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://upload.wikimedia.org/wikipedia/commons/0/06/Syringa_vulgaris_003.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://namethatplant.files.wordpress.com/2010/05/watermark_838.jpg
# [Error]Invalid image, not saving https://namethatplant.files.wordpress.com/2010/05/watermark_838.jpg
#
# [!] Issue getting: https://namethatplant.files.wordpress.com/2010/05/watermark_838.jpg
# [!] Error:: Invalid image, not saving https://namethatplant.files.wordpress.com/2010/05/watermark_838.jpg
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 94 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://www.ornamental-trees.co.uk/images/products/zoom/1489749155-41193400.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Rosa rugosa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://3.bp.blogspot.com/-fccIoIo6f9E/TmZE65tjS3I/AAAAAAAAC0o/8Fxe6MDN01Q/s1600/Sunday+Walk+014.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://img.crocdn.co.uk/images/products2/pl/00/00/07/79/pl0000077954.jpg?width=940&amp;height=940
# [!] Issue getting: http://img.crocdn.co.uk/images/products2/pl/00/00/07/79/pl0000077954.jpg?width=940&amp;height=940
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #2 from https://www.hedgesdirect.co.uk/acatalog/Rosa-Rugosa-Rubra-(Pink-Ramanus-Rose)-Flower-Close-Up.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 94 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://www.thespruce.com/thmb/1nlus6wTYfEvGEpOtt7lIKv49SA=/4629x3643/filters:fill(auto,1)/rugosa-roses--rosa-rugosa---close-up-73898809-5b1d399fba617700378d3520.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Spiraea bumalda
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/f/fc/Spiraea_bumalda_01.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://upload.wikimedia.org/wikipedia/commons/a/a5/Spiraea_bumalda_05.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://upload.wikimedia.org/wikipedia/commons/e/ee/Spiraea_bumalda_03.JPG
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Spiraea vanhouttei
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.pflanzenschleuder.de/bilder/popup/prachtspiere-m000092_h_1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://gartenhit24.de/media/image/product/1007/lg/spiraea-vanhouttei~2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://rasadnik-franceskija.com.hr/wp-content/uploads/2019/11/Spiraea-×-vanhouttei.jpg
# [!] Issue getting: https://rasadnik-franceskija.com.hr/wp-content/uploads/2019/11/Spiraea-×-vanhouttei.jpg
# [!] Error:: 'ascii' codec can't encode character '\xd7' in position 40: ordinal not in range(128)
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://gartenhit24.de/media/image/product/1007/lg/spiraea-vanhouttei.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Potentilla fruticosa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.vivaimarche.it/wp-content/uploads/2021/03/47113977.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.thompson-morgan.com/product_images/100/zoom/z-POTE-T62075-A_h.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://foja.com.mk/wp-content/uploads/2019/09/Potentilla-fruticosa.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Caltha palustris
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Ranunculaceae/caltha-palustris-ha-ahaines-b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.letsgoplanting.co.uk/wp-content/uploads/calthapalustris9.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.heritageflowerfarm.com/wp-content/uploads/2018/02/Caltha-palustris.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Carex capillaris
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Cyperaceae/carex-capillaris-capillaris-in-dcameron.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Cyperaceae/carex-capillaris-fuscidula-ha-ahaines.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Cyperaceae/carex-capillaris-capillaris-le-dcameron.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Carex capitata
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.biopix.com/photos/capitate-sedge-jcs-carex-capitata-17588.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.calflora.org/app/up/entry/343/103048.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.hlasek.com/foto/carex_capitata_11549.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Carex caespitosa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.freenatureimages.eu/Plants/Flora C/Carex caespitosa/Carex caespitosa 2%2C Saxifraga-Jasenka Topic.JPG
# [!] Issue getting: http://www.freenatureimages.eu/Plants/Flora C/Carex caespitosa/Carex caespitosa 2%2C Saxifraga-Jasenka Topic.JPG
# [!] Error:: URL can't contain control characters. '/Plants/Flora C/Carex caespitosa/Carex caespitosa 2%2C Saxifraga-Jasenka Topic.JPG' (found at least ' ')
# [%] Downloading Image #1 from https://www.pflanzen-deutschland.de/bilder/1913x1913/646_foto_Ha_wikipedia_user_rasbak_carex_cespitosa.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.plantarium.ru/dat/plants/6/669/724669_ba92a592.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://www.about-garden.com/images_forum/gallery/14900/27596-ostrice-trsnata-carex-caespitosa-1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Cerastium alpinum
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://botanicallyinclined.org/wp-content/uploads/2017/08/Cerastium-alpinum-ssp.-lanatum.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.plant-world-seeds.com/images/item_images/000/001/829/large_square/CERASTIUM_ALPINUM_LANATUM.JPG?1495388423
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newyorkplantshq.com/wp-content/uploads/Cerastium-alpinum-1507553492.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Dryas octopetala
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://d2seqvvyy3b8p2.cloudfront.net/f073d054e82c367ac985fb523e70332a.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.shopify.com/s/files/1/1069/2032/products/Dryas_octopetala_10_nbrcg_wi_1024x1024.jpg?v=1453911733
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.karensgardentips.com/wp-content/uploads/garden/2030/10/Dryas_octopetala-Wikimedia-e1604346061804-1024x913.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Rubus arcticus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 1 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfoundland-labradorflora.ca/gallery/assets/images/Original/349_6_eosaceae_rubus-arcticus-acaulis_sjm0303_aug10-16_npen_23_02_2019_8_29_55.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 31 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #2 from http://www.minnesotawildflowers.info/udata/r9ndp23q/contrib/rubus-arcticus-fruit-BobArmstrong.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfoundland-labradorflora.ca/gallery/assets/images/Original/344_1_rosaceae_rubus-arcticus-acaulis_sjm3591_aug1-18_bc_23_02_2019_8_29_09.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Polygonum viviparum
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 2 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.francini-mycologie.fr/BOTANIQUE/Polygonum_viviparum_Joly_2015.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.catalogopiante.it/wp-content/uploads/2020/03/polygonum-viviparum-scaled-900x700.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 34 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://c8.alamy.com/comp/J4A3KM/polygonum-viviparum-atlas-alpenflora-J4A3KM.jpg
# [!] Issue getting: https://c8.alamy.com/comp/J4A3KM/polygonum-viviparum-atlas-alpenflora-J4A3KM.jpg
# [!] Error:: <urlopen error [WinError 10054] Удаленный хост принудительно разорвал существующее подключение>
# [%] Downloading Image #3 from http://www.fungoceva.it/erbe_ceb/image_erbe/Polygonum_viviparum.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Saxifraga caespitosa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://nargs.org/sites/default/files/styles/large/public/plant-photos/SaxifragaCaespitosa3_1.JPG?itok=MYVI9F4_
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://stauden.forssman.de/wp-content/uploads/2016/06/Saxifraga-caespitosa-Hitzkopf-20-1-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.whiteflowerfarm.com/mas_assets/cache/image/3/1/1/f/12575.Jpg
# [!] Issue getting: https://www.whiteflowerfarm.com/mas_assets/cache/image/3/1/1/f/12575.Jpg
# [!] Error:: HTTP Error 403: Forbidden
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://garden-tags-live.s3-accelerate.amazonaws.com/28668_jaynehynesburton_1553438813053_1080.jpeg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Sedum acre
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.gardeningknowhow.com/wp-content/uploads/2018/02/Sedum-acre.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://littleprinceplants.com/wp-content/uploads/Sedum-acre-Aureum-MAY4-e1558394610565.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://plantsam.com/wp-content/uploads/2015/06/Sedum-acre.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Sedum spurium
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://littleprinceplants.com/wp-content/uploads/Sedum-spurium-Tricolor-JULY5-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://littleprinceplants.com/wp-content/uploads/Sedum-spurium-John-Creech-JULY4-scaled.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://s3.eu-west-2.amazonaws.com/jparkers/1000/1000765.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Ajuga reptans
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Lamiaceae/ajuga-reptans-fl-ahaines-c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://dkpo4ygqb6rh6.cloudfront.net/APPELTERN_NL/imageresized/32910/8d4b87998d1f9408ad524c42635b7d4b/2048_1536_90_normaljpg/ajuga_reptans_atropurpurea_-_kruipend_zenegroen.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.letsgoplanting.co.uk/wp-content/uploads/2020/01/Ajuga-Reptans-Atropurpurea-2-scaled.jpeg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Asarum europeum
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.woottensplants.com/wp-content/uploads/2015/06/Asarum-europeum.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/94/df/48/94df4812f8c67fa952da9afba407906a.png
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://images.bethchatto.co.uk/1/1446037440_216.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Sedum hybridum
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://cdn11.bigcommerce.com/s-oqm1pc/images/stencil/1280x1280/products/804/9052/sedum_immergrunchen__02117.1560889197.jpg?c=2
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.greenroofplants.com/wp-content/uploads/2017/01/Sedum-hybridum-Immergrunchen-1-c-Green-Roof-Plants.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://dkpo4ygqb6rh6.cloudfront.net/APPELTERN_NL/imageresized/155043/63e596fe964f8aff89519073f15be5e7/1280_720_80_normaljpg/sedum_hybridum_immergrunchen_vetkruid_1280.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Lusula pilosa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.plantarium.ru/dat/plants/4/461/506461_dae291df.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.plantarium.ru/dat/plants/3/391/645391_ba414afb.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://galasearch.de/system/images/30241/original/Luzula_pilosa__Behaarte_Hainsimse_22.jpg?1549665295
# [!] Issue getting: https://galasearch.de/system/images/30241/original/Luzula_pilosa__Behaarte_Hainsimse_22.jpg?1549665295
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1129)>
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://dkpo4ygqb6rh6.cloudfront.net/APPELTERN_NL/imageresized/178355/1dbbbe98e8c01cd1c0b1d1688becddf6/1280_720_80_normaljpg/luzula_pilosa_igel_behaarde_veldbies_1280.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Majanthemum bifolium
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.promessedefleurs.com/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/M/a/Maianthemum-bifolium-8364-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.plantarium.ru/dat/plants/1/121/661121_bf51e4f8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.plantpref.co.uk/user/products/large/maiabifokam.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Gymnocarpium dryopteris
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/e/ef/Gymnocarpium_dryopteris_6035.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Woodsiaceae/gymnocarpium-dryopteris-ha-bpatterson.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Woodsiaceae/gymnocarpium-dryopteris-le-ahaines.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Dryopteris dilatana
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.fernsoftheworld.com/wp-content/uploads/2015/01/IMG_4114-Copy.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.fernsoftheworld.com/wp-content/uploads/2014/06/Dryopteris-Sundue-3134-4-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.alchemyferns.co.uk/wp-content/uploads/2020/03/1200px-Dryopteris_wallichiana_form.jpg
# [!] Issue getting: http://www.alchemyferns.co.uk/wp-content/uploads/2020/03/1200px-Dryopteris_wallichiana_form.jpg
# [!] Error:: Remote end closed connection without response
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from http://www.fernsoftheworld.com/wp-content/uploads/2015/01/IMG_4114-Copy.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Antennaria dioica
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://shop.alpine-peters.de/wp-content/uploads/2020/07/Antenaris-diorica-Alex-Daguid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://plantsam.com/wp-content/uploads/2014/05/Antennaria-dioica-6.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://mihkelsaar.ee/wp-content/uploads/2020/11/Antennaria-dioica-Alex-Duguid1.1-e1605881176828.jpeg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Campanula persicifolia
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Campanulaceae/campanula-persicifolia-fl-pdrobot-b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.whiteflowerfarm.com/mas_assets/cache/image/3/5/7/d/13693.Jpg
# [!] Issue getting: https://www.whiteflowerfarm.com/mas_assets/cache/image/3/5/7/d/13693.Jpg
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #2 from https://plants4home.com/wp-content/uploads/2019/12/49E0B40C-EDE6-4EBD-9FF0-0714A51D4B5C.jpeg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 95 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://bethchatto.2dimg.com/1/campanula-persicifolia-2_9f13ce664b.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Convallaria majalis
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://img.crocdn.co.uk/images/products2/pl/20/00/01/80/pl2000018093.jpg?width=940&amp;height=940
# [!] Issue getting: https://img.crocdn.co.uk/images/products2/pl/20/00/01/80/pl2000018093.jpg?width=940&amp;height=940
# [!] Error:: HTTP Error 403: Forbidden
# [%] Downloading Image #1 from https://worldoffloweringplants.com/wp-content/uploads/2014/03/Convallaria-majalis-Lily-of-the-Valley1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://cdn.shopify.com/s/files/1/1069/2032/products/Convallaria_majalis_1_1024x1024.jpeg?v=1453888584
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 95 Images on Page 2.
#
# ===============================================
#
# ...
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 2 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://waspweb.org/Apoidea/Ampulicidae/Ampulicinae/Ampulex/images/Ampulex_with_prey_Deropeltis_Dion_Brandt_DSC_0091_cpd_680.jpg
# [!] Issue getting: http://waspweb.org/Apoidea/Ampulicidae/Ampulicinae/Ampulex/images/Ampulex_with_prey_Deropeltis_Dion_Brandt_DSC_0091_cpd_680.jpg
# [!] Error:: <urlopen error [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера>
# [%] Downloading Image #1 from https://www.waspweb.org/Apoidea/Ampulicidae/Ampulicinae/Ampulex/images/Ampulex_bredoi_Syntype_female_habitus_lateral.jpg
# [!] Issue getting: https://www.waspweb.org/Apoidea/Ampulicidae/Ampulicinae/Ampulex/images/Ampulex_bredoi_Syntype_female_habitus_lateral.jpg
# [!] Error:: <urlopen error [WinError 10060] Попытка установить соединение была безуспешной, т.к. от другого компьютера за требуемое время не получен нужный отклик, или было разорвано уже установленное соединение из-за неверного отклика уже подключенного компьютера>
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 34 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #1 from https://m.psecn.photoshelter.com/img-get/I0000aMO3Lv_Znxc/s/880/880/AH-Platypelis-grandis-juvenile-4-5554.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.enature.qa/wp-content/uploads/2017/09/Amphibalanus-amphitrite_F-Krupp-1200P800-1200x800.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://live.staticflickr.com/65535/51149944007_c84816efe9_b.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Trollius europaeus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.devonpondplants.co.uk/wp-content/uploads/2018/10/Trollius-europaeus.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://images.bethchatto.co.uk/4/1456318597_2452.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://bethchatto.2dimg.com/1/trollius-europaeus-15-5-21a_601e119c32.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Polygonum bistorta
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://bugwoodcloud.org/images/1536x1024/5424706.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/b3/1d/39/b31d39b05ad5e4559ba3389fd4dbeacd.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://www.scientificlib.com/en/Biology/Plants/Magnoliophyta/images/PolygonumBistorta1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Lichnis flos-cuculi
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.heritageflowerfarm.com/wp-content/uploads/2018/02/Lychnis-flos-cuculi.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.penlanperennials.co.uk/wp-content/uploads/2015/11/Lychnis-flos-cuculi.18431.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Caryophyllaceae/lychnis-flos-cuculi-fl-ahaines-c.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Phalaris arundinaceae
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://upload.wikimedia.org/wikipedia/commons/0/07/Phalaris_arundinacea_001.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Poaceae/phalaris-arundinacea-in-gmittelhauser-b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i0.wp.com/weedwise.conservationdistrict.org/wp-content/uploads/sites/2/2016/02/Phalaris_arundinacea_flowers_rietgras_bloempjes_1WWLS.jpg?fit=960%2C960&amp;ssl=1
# [!] Issue getting: https://i0.wp.com/weedwise.conservationdistrict.org/wp-content/uploads/sites/2/2016/02/Phalaris_arundinacea_flowers_rietgras_bloempjes_1WWLS.jpg?fit=960%2C960&amp;ssl=1
# [!] Error:: HTTP Error 404: Not Found
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://live.staticflickr.com/2659/3882414219_ece73c27b7_b.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Astilbe hybrida
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://greenseasons.eu/wp-content/uploads/2017/06/astilbe-hybrid-mighty-pip-.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://pitomnikhutorok.ru/assets/cache/images/astilby/ast-yn-red-x-726.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.gardeningknowhow.com/wp-content/uploads/2012/03/astilbe-1-1536x1152.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Hemerocalis hybrida
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.boethingtreeland.com/wp-content/uploads/2018/02/hemerocallis-hybrid-orange.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.zahrada-cs.com/images_forum/gallery/10667/31433-p3010187.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.garden-en.com/images_forum/gallery/12147/34915-denivka-corky-as.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Deschampsia caespitosa
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from http://www.watershednursery.com/wp-content/uploads/2012/09/Deschampsia-cespitosa.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://bakerenvironmentalnursery.com/wp-content/uploads/2015/04/d_caespitosa.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://s3.amazonaws.com/eit-planttoolbox-prod/media/images/Deschampsia_cespitos_BAJcbR4l45Io.jpe
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Thelypteris palustris
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://bakerenvironmentalnursery.com/wp-content/uploads/2015/08/Thelypteris_palustris_Russia_2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Thelypteridaceae/thelypteris-palustris-le-gmittelhauser.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Thelypteridaceae/thelypteris-palustris-ld-gmittelhauser-a.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Ranunculus repens pleniflorus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.devonpondplants.co.uk/wp-content/uploads/2018/10/Ranunculus-repens-Pleniflorus-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.heritageflowerfarm.com/wp-content/uploads/2018/02/Ranunculus-repens.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.heritageflowerfarm.com/wp-content/uploads/2018/02/Ranun-repensMG_0603.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Filipendula ulmaria
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.devonpondplants.co.uk/wp-content/uploads/2018/10/Filipendula-ulmaria.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i.pinimg.com/originals/09/9c/18/099c181c03446f19c8d004375d84380b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.norasperennials.com/wp-content/uploads/2018/04/filipendulavulgaris-1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Sagittaria latifolia
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://mellowmarshfarm.com/wp-content/uploads/2022/02/DETA-7234_Sagittaria-latifolia.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Alismataceae/sagittaria-latifolia-le-ahaines-c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Alismataceae/sagittaria-latifolia-in-dcameron-a.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Acorus calamus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.devonpondplants.co.uk/wp-content/uploads/2018/10/Acorus-calamus-variegatus.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.pondplants.co.uk/wp-content/uploads/2016/10/acorus_calamus_general_margional_plants_Merebrook_Plants1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://eruvaaka.com/wp-content/uploads/2022/05/Acorus-Calamus.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Typha laxmannii
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://kiefernursery.com/wp-content/uploads/2017/11/tl2.jpg
# [!] Issue getting: https://kiefernursery.com/wp-content/uploads/2017/11/tl2.jpg
# [!] Error:: <urlopen error [WinError 10054] Удаленный хост принудительно разорвал существующее подключение>
# [%] Downloading Image #1 from https://www.plantarium.ru/dat/plants/9/972/560972_cf34d685.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.devonpondplants.co.uk/wp-content/uploads/2018/10/Typha-laxmannii.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://botanik-bochum.de/web/sites/default/files/2021-02/Typha_laxmannii_110718_HGeier05.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Carex paniculata
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.devonpondplants.co.uk/wp-content/uploads/2020/11/Carex-paniculata-768x1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.wasserpflanzen-shopping.de/media/image/e3/70/96/Carex-paniculata-012.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.preservons-la-nature.fr/flore/images/219/DSC02310_1600.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Bolboschoenus maritimus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://d2seqvvyy3b8p2.cloudfront.net/6bb3084e9149c0f34e37be806e2b81fc.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://newfs.s3.amazonaws.com/taxon-images-1000s1000/Cyperaceae/bolboschoenus-maritimus-palodosus-ff-gmittelhauser.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://d2seqvvyy3b8p2.cloudfront.net/ec65186c3cc269abafda8099dddfc34d.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Butomus umbellatus
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://artisanaquatics.co.uk/wp-content/uploads/2019/07/artisan_aquatics_butomus_umbellatus.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.aziendanaturaviva.com/wp-content/uploads/2018/09/BUTOMUS-OMBELLATUS.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.rasadniksombor.rs/image/cache/catalog/Butomus_umbellatus-1600x1600.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Menyanthes trifoliata
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.pondplants.co.uk/wp-content/uploads/2017/01/Menyanthes_trifoliata_marginal_bog_wetland_Merebrook_pondplants.jpg
# [Error]Invalid image, not saving https://www.pondplants.co.uk/wp-content/uploads/2017/01/Menyanthes_trifoliata_marginal_bog_wetland_Merebrook_pondplants.jpg
#
# [!] Issue getting: https://www.pondplants.co.uk/wp-content/uploads/2017/01/Menyanthes_trifoliata_marginal_bog_wetland_Merebrook_pondplants.jpg
# [!] Error:: Invalid image, not saving https://www.pondplants.co.uk/wp-content/uploads/2017/01/Menyanthes_trifoliata_marginal_bog_wetland_Merebrook_pondplants.jpg
#
# [%] Downloading Image #1 from http://www.plantsystematics.org/users/jdelaet/6_22_08_4/oeploa694/nDSC_3217.JPG
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://live.staticflickr.com/8165/7569601226_68099d5ab8_b.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://img2.juzaphoto.com/001/shared_files/uploads_hr/1359854_large55888.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Nyphar lutea ssp.lutea
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 3 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://www.devonpondplants.co.uk/wp-content/uploads/2018/10/Nuphar-lutea-pumila.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.plantarium.ru/dat/plants/9/971/458971_74fb1828.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://media.sciencephoto.com/image/b8260563/800wm/B8260563-Nuphar_lutea.jpg
# [!] Issue getting: https://media.sciencephoto.com/image/b8260563/800wm/B8260563-Nuphar_lutea.jpg
# [!] Error:: <urlopen error [WinError 10054] Удаленный хост принудительно разорвал существующее подключение>
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 35 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from https://www.vijverplantenland.nl/wp-content/uploads/2018/02/Nuphar-lutea-5-1024x768.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.
# [%] Downloading Images to c:\IDE\Zaradye_bot\plant_images\Nymphaea candida
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 2 Images on Page 1.
#
# ===============================================
#
# [%] Downloading Image #1 from https://worldoffloweringplants.com/wp-content/uploads/2019/01/Nymphaea-candida-Dwarf-White-Water-Lily2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://upload.wikimedia.org/wikipedia/commons/f/fc/Lumme_(Nymphaea_candida).JPG
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 33 Images on Page 2.
#
# ===============================================
#
# [%] Downloading Image #3 from http://flora.nhm-wien.ac.at/Bilder-G-O/Nymphaea-candida-1.jpg
# [%] File Downloaded !
#
#
#
# [%] Done. Downloaded 3 images.

# %%
# Код для поиска растений и вывода информации по ним

def text_to_speech(text):
    """Преобразует текст в речь и возвращает путь к аудиофайлу"""
    tts = gTTS(text=text, lang='ru')  # Создаем объект gTTS с текстом и языком
    tts.save('response.mp3')  # Сохраняем аудиофайл
    return 'response.mp3'  # Возвращаем путь к аудиофайлу

def get_plant_images(latin_name):
    """Получает пути к изображениям для данного латинского названия растения"""
    image_dir = f'C:/Users/DS/Desktop/Зарядье/zaryadye_bot/plant_images/{latin_name}'  # Путь к папке с изображениями
    if os.path.exists(image_dir):  # Проверяем, существует ли папка
        return sorted(glob.glob(f'{image_dir}/Image_*.jpg'))  # Возвращаем отсортированные пути к изображениям
    return []  # Если папка не существует, возвращаем пустой список

def get_plant_info(question, speak=True):
    """Обрабатывает вопросы пользователя и возвращает информацию о растениях"""
    # Проверка на наличие запроса о хвойных растениях
    if 'хвойные' in question.lower():
        conifer_plants = df_plants[df_plants['LandscapingZone'].str.contains('Хвойный', na=False)]
        response = f"Хвойные растения в парке:\n" + "\n".join(conifer_plants['Name'].tolist())
        return response, text_to_speech(response) if speak else None, []

    # Проверка на запрос всех растений
    if 'все растения' in question.lower() or 'список растений' in question.lower():
        response = "Растения в парке:\n" + "\n".join(df_plants['Name'].tolist())
        return response, text_to_speech(response) if speak else None, []

    # Поиск растения с использованием fuzzy matching
    max_ratio = 0
    matched_name = None
    for name in df_plants['Name'].unique():
        ratio = fuzz.partial_ratio(name.lower(), question.lower())  # Вычисляем коэффициент схожести
        if ratio > max_ratio and ratio > 70:  # Проверяем, если коэффициент выше 70
            max_ratio = ratio
            matched_name = name  # Сохраняем найденное название

    # Если найдено соответствующее название растения
    if matched_name:
        plant = df_plants[df_plants['Name'] == matched_name].iloc[0]  # Получаем информацию о растении
        latin_name = plant['LatinName']  # Получаем латинское название
        images = get_plant_images(latin_name)  # Получаем изображения растения

        # Определяем ответ в зависимости от вопроса
        if any(word in question.lower() for word in ['где', 'расположен', 'растет']):
            response = f"{matched_name} расположен в {plant['LocationPlace']}"
        elif any(word in question.lower() for word in ['когда', 'цветет', 'цветение']):
            response = f"{matched_name} цветет в период: {plant['ProsperityPeriod']}"
        elif 'латинск' in question.lower():
            response = f"Латинское название {matched_name}: {plant['LatinName']}"
        else:
            response = f"{plant['Description']}"  # Возвращаем описание растения

        return response, text_to_speech(response) if speak else None, images

    # Проверка на запрос о растениях смешанного леса
    if 'смешанный лес' in question.lower():
        mixed_forest = df_plants[df_plants['LandscapingZone'].str.contains('Смешанный', na=False)]
        response = f"Растения смешанного леса:\n" + "\n".join(mixed_forest['Name'].tolist())
        return response, text_to_speech(response) if speak else None, []

    # Если вопрос не распознан
    response = "Уточните вопрос. Вы можете спросить о конкретном растении или группе растений."
    return response, text_to_speech(response) if speak else None, []

# Создаем интерфейс Gradio
iface = gr.Interface(
    fn=get_plant_info,  # Функция для обработки вопросов
    inputs=[
        gr.Textbox(lines=2, placeholder="Задайте вопрос о растениях парка"),  # Поле для ввода вопроса
        gr.Checkbox(label="Озвучить ответ", value=True)  # Чекбокс для выбора озвучивания ответа
    ],
    outputs=[
        gr.Textbox(label="Текстовый ответ"),  # Поле для текстового ответа
        gr.Audio(label="Аудио ответ"),  # Поле для аудиоответа
        gr.Gallery(label="Изображения растения")  # Галерея для отображения изображений
    ],
    title="🌳 Справочник растений парка Зарядье",  # Заголовок приложения
    description="Задавайте вопросы о растениях или группах растений. Для каждого растения доступны фотографии.",  # Описание приложения
    examples=[
        ["Какие хвойные растения есть в парке?", True],
        ["Где растет Ель?", True],
        ["Покажи все растения смешанного леса", True],
        ["Когда цветет Липа?", True],
        ["Расскажи про Дуб", True],
        ["Список всех растений", True]
    ]  # Примеры вопросов для интерфейса
)

iface.launch(share=True)  # Запускаем интерфейс и делимся ссылкой
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://ce44ec4ff999c4d263.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://ce44ec4ff999c4d263.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
